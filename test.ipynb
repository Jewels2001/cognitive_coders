# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('experiment.csv')

# %%
display(data)
# Out:
#        Unnamed: 0       TP9     AF7     AF8      TP10  Right AUX    timestamps
# 0               0     0.000   0.000   0.000     0.000        0.0  1.731708e+09
# 1               1     0.000   0.000   0.000     0.000        0.0  1.731708e+09
# 2               2   -32.227  -0.977  -0.977   -32.227        0.0  1.731708e+09
# 3               3    70.312   0.977   1.953    70.312        0.0  1.731708e+09
# 4               4  -396.484  -6.836 -10.254  -396.484        0.0  1.731708e+09
# ...           ...       ...     ...     ...       ...        ...           ...
# 15379       15379  -925.781 -40.527 -27.832  -929.199        0.0  1.731708e+09
# 15380       15380 -1000.000 -39.062 -31.250 -1000.000        0.0  1.731708e+09
# 15381       15381  -526.855 -13.672 -30.273  -427.734        0.0  1.731708e+09
# 15382       15382   903.809   2.930 -26.855   950.684        0.0  1.731708e+09
# 15383       15383  -990.723  -4.395 -30.273   991.699        0.0  1.731708e+09
#
# [15384 rows x 7 columns]

# %%
for column in data.columns:
    fig = plt.figure()
    plt.plot(data[column], label=column)
